# %%
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#scaling (optional) >> brings all the feature on the same scale

# %%
#why scaling? --- To reduce the computation time(faster optimisation) and better interpretation

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Very Important for Interview Questions
# ############# STARTS ##############

# %%
#standardisation >> zscore = x-mu/sigma
mean = np.mean(df['total_bill'])

# %%
std = np.std(df['total_bill'])

# %%
std_data = []
for i in list(df['total_bill']):
    zscore = (i-mean)/std
    std_data.append(zscore)

# %%
std_data
# Out:
# [-0.31471130509049433,
#  -1.0632353132988694,
#  0.13777989987156147,
#  0.4383151031672548,
#  0.5407447042905061,
#  0.6195367051545456,
#  -1.2399545152367868,
#  0.7985071071171497,
#  -0.5342033074974615,
#  -0.5634689078183904,
#  -1.0711145133852735,
#  1.7417599174609368,
#  -0.49143050702841135,
#  -0.1526249033130415,
#  -0.5578409077566732,
#  0.20193910057513614,
#  -1.0643609133112129,
#  -0.39350330595453376,
#  -0.31696250511518115,
#  0.09725829942719796,
#  -0.21003050394255576,
#  0.05673669898283485,
#  -0.4520345065963916,
#  2.2100095225958007,
#  0.0038334984026941687,
#  -0.22241210407833373,
#  -0.7221785095588128,
#  -0.7987193103981655,
#  0.2154463007232573,
#  -0.01530170180714419,
#  -1.1521577142739996,
#  -0.16162970341178867,
#  -0.5319521074727744,
#  0.10176069947657196,
#  -0.22578890411536373,
#  0.4810879036363047,
#  -0.39125210592984694,
#  -0.3214649051645547,
#  -0.12335930299211235,
#  1.2926455125359118,
#  -0.4216433062631193,
# ...

# %%
# scaling is optional because scaling doesnt change the distribution of data
# scaling is the best practice to do

#before scaling
sns.distplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#after scaling
sns.distplot(std_data)
# Out:
# <Axes: ylabel='Density'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
# Doing Fit One column at a time
scaler.fit(df[['total_bill']]) #fit will calculate mu and sigma
# Out:
# StandardScaler()

# %%
# Doing transform One column at a time
scaler.transform(df[['total_bill']]) #apply the params to a formulae(computation)
# Out:
# array([[-3.14711305e-01],
#        [-1.06323531e+00],
#        [ 1.37779900e-01],
#        [ 4.38315103e-01],
#        [ 5.40744704e-01],
#        [ 6.19536705e-01],
#        [-1.23995452e+00],
#        [ 7.98507107e-01],
#        [-5.34203307e-01],
#        [-5.63468908e-01],
#        [-1.07111451e+00],
#        [ 1.74175992e+00],
#        [-4.91430507e-01],
#        [-1.52624903e-01],
#        [-5.57840908e-01],
#        [ 2.01939101e-01],
#        [-1.06436091e+00],
#        [-3.93503306e-01],
#        [-3.16962505e-01],
#        [ 9.72582994e-02],
#        [-2.10030504e-01],
#        [ 5.67366990e-02],
#        [-4.52034507e-01],
#        [ 2.21000952e+00],
#        [ 3.83349840e-03],
#        [-2.22412104e-01],
#        [-7.22178510e-01],
#        [-7.98719310e-01],
#        [ 2.15446301e-01],
#        [-1.53017018e-02],
#        [-1.15215771e+00],
#        [-1.61629703e-01],
#        [-5.31952107e-01],
#        [ 1.01760699e-01],
#        [-2.25788904e-01],
# ...

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Doing Fit and transform 2 columns at a time
scaler.fit_transform(df[['total_bill', 'tip']])
# Out:
# array([[-3.14711305e-01, -1.43994695e+00],
#        [-1.06323531e+00, -9.69205340e-01],
#        [ 1.37779900e-01,  3.63355539e-01],
#        [ 4.38315103e-01,  2.25754144e-01],
#        [ 5.40744704e-01,  4.43019505e-01],
#        [ 6.19536705e-01,  1.23965916e+00],
#        [-1.23995452e+00, -7.22971264e-01],
#        [ 7.98507107e-01,  8.81527488e-02],
#        [-5.34203307e-01, -7.51939979e-01],
#        [-5.63468908e-01,  1.67816714e-01],
#        [-1.07111451e+00, -9.32994446e-01],
#        [ 1.74175992e+00,  1.44968234e+00],
#        [-4.91430507e-01, -1.03438495e+00],
#        [-1.52624903e-01,  1.24660453e-03],
#        [-5.57840908e-01,  1.57309619e-02],
#        [ 2.01939101e-01,  6.67527044e-01],
#        [-1.06436091e+00, -9.61963161e-01],
#        [-3.93503306e-01,  5.15441291e-01],
#        [-3.16962505e-01,  3.63355539e-01],
#        [ 9.72582994e-02,  2.54722859e-01],
#        [-2.10030504e-01,  7.83401903e-01],
#        [ 5.67366990e-02, -1.79807863e-01],
# ...

# %%
pd.DataFrame(scaler.fit_transform(df[['total_bill', 'tip']]), columns = ['total_bill', 'tip'])
# Out:
#      total_bill       tip
# 0     -0.314711 -1.439947
# 1     -1.063235 -0.969205
# 2      0.137780  0.363356
# 3      0.438315  0.225754
# 4      0.540745  0.443020
# ..          ...       ...
# 239    1.040511  2.115963
# 240    0.832275 -0.722971
# 241    0.324630 -0.722971
# 242   -0.221287 -0.904026
# 243   -0.113229  0.001247
#
# [244 rows x 2 columns]

# %%
# new data comes into the picture
scaler.transform([[13, 1]])

# New data is considered as test data
# Out:
# array([[-0.76382571, -1.44718913]])

# %%
# Very Important for Interview Questions
# ############# ENDS ##############

# %%
#Normalization/minmax scaling
from sklearn.preprocessing import MinMaxScaler

# ML algorithm we use standardization
# PCA we use min/max scaler

# %%
min_max = MinMaxScaler()

# %%
min_max.fit_transform(df[['total_bill', 'tip']])
# Out:
# array([[0.29157939, 0.00111111],
#        [0.1522832 , 0.07333333],
#        [0.3757855 , 0.27777778],
#        [0.43171345, 0.25666667],
#        [0.45077503, 0.29      ],
#        [0.46543779, 0.41222222],
#        [0.11939673, 0.11111111],
#        [0.49874319, 0.23555556],
#        [0.25073314, 0.10666667],
#        [0.24528697, 0.24777778],
#        [0.15081693, 0.07888889],
#        [0.67427734, 0.44444444],
#        [0.25869292, 0.06333333],
#        [0.32174277, 0.22222222],
#        [0.24633431, 0.22444444],
#        [0.38772518, 0.32444444],
#        [0.15207373, 0.07444444],
#        [0.27691663, 0.30111111],
#        [0.29116045, 0.27777778],
#        [0.36824466, 0.26111111],
#        [0.31105991, 0.34222222],
#        [0.36070381, 0.19444444],
#        [0.2660243 , 0.13666667],
#        [0.761416  , 0.73111111],
#        [0.35085882, 0.24222222],
#        [0.30875576, 0.14888889],
#        [0.21575199, 0.11111111],
#        [0.20150817, 0.11111111],
# ...

# %%
# new data comes we use transform
min_max.transform([[10, 8]])
# Out:
# array([[0.14516129, 0.77777778]])

# %%
#unit vector
from sklearn.preprocessing import normalize

# %%
normalize(df[['total_bill', 'tip']])
# every time unit vector need 2 parametes
# if 1 parameter is provided then output is 1,1,1,1.....

# when we will use unit vector in ML?
# we always use standardization or normalisation techniques because they are important.

# is there any scaling techniques?
# yes
# Out:
# array([[0.99823771, 0.05934197],
#        [0.98735707, 0.15851187],
#        [0.98640661, 0.16432285],
#        [0.99037159, 0.13843454],
#        [0.98939488, 0.14525073],
#        [0.98309589, 0.18309141],
#        [0.97496878, 0.2223418 ],
#        [0.99333102, 0.11529735],
#        [0.99161511, 0.12922644],
#        [0.97694312, 0.21349975],
#        [0.98641987, 0.16424323],
#        [0.99009498, 0.14039917],
#        [0.99485672, 0.10129216],
#        [0.98700924, 0.16066347],
#        [0.97988851, 0.19954574],
#        [0.98389908, 0.17872495],
#        [0.9871829 , 0.15959298],
#        [0.9750328 , 0.22206088],
#        [0.97938658, 0.20199487],
#        [0.98709527, 0.1601341 ],
#        [0.97504726, 0.22199737],
#        [0.9909398 , 0.13430677],
#        [0.99014941, 0.14001479],
#        [0.98201   , 0.18882891],
#        [0.98737215, 0.15841793],
#        [0.99147891, 0.1302673 ],
#        [0.98899596, 0.14794255],
#        [0.98780711, 0.15568276],
# ...

# %%
# How to do scaling when you have outliers?
# use robust scaling

# very important
#robust scaling >> It is used when ever you have outliers the data 
#X-median/IQR

# %%
from sklearn.preprocessing import RobustScaler

rs = RobustScaler()

# %%
rs
# Out:
# RobustScaler()

# %%
rs.fit_transform(df[['total_bill', 'tip']])
# Out:
# array([[-7.46753247e-02, -1.20960000e+00],
#        [-6.91558442e-01, -7.93600000e-01],
#        [ 2.98237477e-01,  3.84000000e-01],
#        [ 5.45918367e-01,  2.62400000e-01],
#        [ 6.30333952e-01,  4.54400000e-01],
#        [ 6.95269017e-01,  1.15840000e+00],
#        [-8.37198516e-01, -5.76000000e-01],
#        [ 8.42764378e-01,  1.40800000e-01],
#        [-2.55565863e-01, -6.01600000e-01],
#        [-2.79684601e-01,  2.11200000e-01],
#        [-6.98051948e-01, -7.61600000e-01],
#        [ 1.62012987e+00,  1.34400000e+00],
#        [-2.20315399e-01, -8.51200000e-01],
#        [ 5.89053803e-02,  6.40000000e-02],
#        [-2.75046382e-01,  7.68000000e-02],
#        [ 3.51113173e-01,  6.52800000e-01],
#        [-6.92486085e-01, -7.87200000e-01],
#        [-1.39610390e-01,  5.18400000e-01],
#        [-7.65306122e-02,  3.84000000e-01],
#        [ 2.64842301e-01,  2.88000000e-01],
#        [ 1.15955473e-02,  7.55200000e-01],
#        [ 2.31447124e-01, -9.60000000e-02],
# ...

# %%
#internal homework
# do scaling all methods you have learnt as above starting of the page
df_1 = sns.load_dataset("taxis")
df_1
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
#standardisation >> zscore = x-mu/sigma
mean_1 = np.mean(df_1['fare'])
std_1 = np.std(df_1['fare'])
std_data_1 = []
for i in list(df_1['fare']):
    zscore_1 = (i-mean_1)/std_1
    std_data_1.append(zscore_1)

std_data_1

# Doubt:
# Can I choose any numerical column from data set?
# Out:
# [-0.5273242112750546,
#  -0.7004707969049286,
#  -0.4840375648675861,
#  1.204141645023686,
#  -0.35417762564518057,
#  -0.4840375648675861,
#  -0.007884454385432447,
#  -0.39746427205264906,
#  0.1652621312444416,
#  -0.4407509184601176,
#  0.3384087168743157,
#  -0.5706108576825231,
#  -0.5706108576825231,
#  -0.22431768642277503,
#  -0.137744393607838,
#  0.035402192022036066,
#  -0.007884454385432447,
#  -0.22431768642277503,
#  -0.31089097923771203,
#  -0.5706108576825231,
#  -0.5706108576825231,
#  -0.6571841504974602,
#  1.5937214626909026,
#  -0.39746427205264906,
#  -0.31089097923771203,
#  -0.26760433283024354,
#  0.035402192022036066,
#  -0.05117110079290096,
#  0.38169536328178416,
#  -0.09445774720036948,
#  -0.5273242112750546,
#  -0.7870440897198657,
#  -0.6571841504974602,
#  -0.7437574433123971,
#  -0.4840375648675861,
#  0.3384087168743157,
#  -0.6571841504974602,
#  0.6414152417265953,
#  -0.5706108576825231,
#  -0.26760433283024354,
#  1.204141645023686,
# ...

# %%
# scaling is optional because scaling doesnt change the distribution of data
# scaling is the best practice to do

#before scaling
sns.distplot(df_1['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Density'>

# %%
#after scaling
sns.distplot(std_data_1)
# Out:
# <Axes: ylabel='Density'>

# %%
scaler_1 = StandardScaler()
scaler_1
# Out:
# StandardScaler()

# %%
# Doing Fit One column at a time
scaler_1.fit(df_1[['fare']]) #fit will calculate mu and sigma
# Out:
# StandardScaler()

# %%
# Doing transform One column at a time
scaler_1.transform(df_1[['fare']]) #apply the params to a formulae(computation)
# Out:
# array([[-0.52732421],
#        [-0.7004708 ],
#        [-0.48403756],
#        ...,
#        [ 0.25183542],
#        [-0.6138975 ],
#        [ 0.16526213]])

# %%
df_1
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
# Doing Fit and transform 2 columns at a time
scaler_1.fit_transform(df_1[['fare', 'tip']])
# Out:
# array([[-0.52732421,  0.06975269],
#        [-0.7004708 , -0.80838282],
#        [-0.48403756,  0.15552407],
#        ...,
#        [ 0.25183542, -0.80838282],
#        [-0.6138975 , -0.80838282],
#        [ 0.16526213,  0.56395919]])

# %%
pd.DataFrame(scaler_1.fit_transform(df_1[['fare', 'tip']]), columns = ['fare', 'tip'])
# Out:
#           fare       tip
# 0    -0.527324  0.069753
# 1    -0.700471 -0.808383
# 2    -0.484038  0.155524
# 3     1.204142  1.703493
# 4    -0.354178 -0.359104
# ...        ...       ...
# 6428 -0.743757 -0.375442
# 6429  3.887914 -0.808383
# 6430  0.251835 -0.808383
# 6431 -0.613898 -0.808383
# 6432  0.165262  0.563959
#
# [6433 rows x 2 columns]

# %%
# new data comes into the picture
scaler_1.transform([[10, 5]])

# New data is considered as test data
# Out:
# array([[-0.26760433,  1.23379279]])

# %%
#Normalization/minmax scaling
from sklearn.preprocessing import MinMaxScaler

# ML algorithm we use standardization
# PCA we use min/max scaler

# %%
min_max_1 = MinMaxScaler()
min_max_1.fit_transform(df_1[['fare', 'tip']])
# Out:
# array([[0.04026846, 0.06475904],
#        [0.02684564, 0.        ],
#        [0.04362416, 0.07108434],
#        ...,
#        [0.10067114, 0.        ],
#        [0.03355705, 0.        ],
#        [0.09395973, 0.10120482]])

# %%
# new data comes we use transform
min_max_1.transform([[15, 7]])
# Out:
# array([[0.09395973, 0.21084337]])

# %%
#unit vector
from sklearn.preprocessing import normalize

normalize(df_1[['fare', 'tip']])
# every time unit vector need 2 parametes
# if 1 parameter is provided then output is 1,1,1,1.....

# when we will use unit vector in ML?
# we always use standardization or normalisation techniques because they are important.

# is there any scaling techniques?
# yes
# Out:
# array([[0.95592652, 0.293606  ],
#        [1.        , 0.        ],
#        [0.95388972, 0.3001573 ],
#        ...,
#        [1.        , 0.        ],
#        [1.        , 0.        ],
#        [0.97581829, 0.2185833 ]])

# %%
# How to do scaling when you have outliers?
# use robust scaling

# very important
#robust scaling >> It is used when ever you have outliers the data 
#X-median/IQR

from sklearn.preprocessing import RobustScaler

rs_1 = RobustScaler()
rs_1
# Out:
# RobustScaler()

# %%
rs_1.fit_transform(df_1[['fare', 'tip']])
# Out:
# array([[-0.29411765,  0.16071429],
#        [-0.52941176, -0.60714286],
#        [-0.23529412,  0.23571429],
#        ...,
#        [ 0.76470588, -0.60714286],
#        [-0.41176471, -0.60714286],
#        [ 0.64705882,  0.59285714]])
