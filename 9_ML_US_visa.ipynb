# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px


import warnings
warnings.filterwarnings('ignore')


plt.style.use("fivethirtyeight")
# %matplotlib inline

pd.set_option('display.max_columns', 30)

# %%
# ****************************** 
# EDA_3 : US Visa Data Set 
# ****************************** 

df = pd.read_csv("us_perm_visas.csv")

# %%
df
# Out:
#         add_these_pw_job_title_9089  agent_city  agent_firm_name  agent_state  \
# 0                              4276        1838            10135          108
# 1                              4276        1838            10135          108
# 2                              4276        1838            10135          108
# 3                              4276        1838            10135          108
# 4                              4276        1838            10135          108
# ...                             ...         ...              ...          ...
# 374357                         4276         187             6316            8
# 374358                         4276        1460             6772          101
# 374359                         4276        1454             3180           29
# 374360                         4276         786             4212            8
# 374361                         4276        1229             2171            7
#
# ...

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        ...
#        'ri_pvt_employment_firm_to', 'ri_us_workers_considered',
#        'schd_a_sheepherder', 'us_economic_sector', 'wage_offer_from_9089',
#        'wage_offer_to_9089', 'wage_offer_unit_of_pay_9089',
#        'wage_offered_from_9089', 'wage_offered_to_9089',
#        'wage_offered_unit_of_pay_9089'],
#       dtype='object', length=154)

# %%
df.shape
# Out:
# (374362, 154)

# %%
df.isnull().sum()
# Out:
# add_these_pw_job_title_9089           0
# agent_city                            0
# agent_firm_name                       0
# agent_state                           0
# application_type                      0
#                                   ...
# wage_offer_to_9089               300728
# wage_offer_unit_of_pay_9089      115916
# wage_offered_from_9089           259715
# wage_offered_to_9089             343347
# wage_offered_unit_of_pay_9089    303663
# Length: 154, dtype: int64

# %%
df.dtypes
# Out:
# add_these_pw_job_title_9089        int64
# agent_city                         int64
# agent_firm_name                    int64
# agent_state                        int64
# application_type                   int64
#                                   ...
# wage_offer_to_9089                object
# wage_offer_unit_of_pay_9089       object
# wage_offered_from_9089           float64
# wage_offered_to_9089             float64
# wage_offered_unit_of_pay_9089     object
# Length: 154, dtype: object

# %%
df.shape
# Out:
# (374362, 154)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374362 entries, 0 to 374361
# Columns: 154 entries, add_these_pw_job_title_9089 to wage_offered_unit_of_pay_9089
# dtypes: float64(9), int64(21), object(124)
# memory usage: 439.8+ MB

# %%
df.describe()
# Out:
#        add_these_pw_job_title_9089     agent_city  agent_firm_name  \
# count                374362.000000  374362.000000    374362.000000
# mean                   4057.646398    1313.656429      6911.476325
# std                     744.083164     602.153206      3636.507555
# min                       0.000000       0.000000         0.000000
# 25%                    4276.000000     914.000000      2541.000000
# 50%                    4276.000000    1454.000000      8755.000000
# 75%                    4276.000000    1838.000000     10135.000000
# max                    4276.000000    1838.000000     10135.000000
#
#          agent_state  application_type        case_no    case_number  \
# count  374362.000000     374362.000000  374362.000000  374362.000000
# mean       71.880060          2.326612  110595.541764  162294.444818
# std        40.133478          0.924892   40000.630094   79390.529944
# min         0.000000          0.000000       0.000000       0.000000
# ...

# %%
df
# Out:
#         add_these_pw_job_title_9089  agent_city  agent_firm_name  agent_state  \
# 0                              4276        1838            10135          108
# 1                              4276        1838            10135          108
# 2                              4276        1838            10135          108
# 3                              4276        1838            10135          108
# 4                              4276        1838            10135          108
# ...                             ...         ...              ...          ...
# 374357                         4276         187             6316            8
# 374358                         4276        1460             6772          101
# 374359                         4276        1454             3180           29
# 374360                         4276         786             4212            8
# 374361                         4276        1229             2171            7
#
# ...

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        'country_of_citizenship', 'country_of_citzenship', 'decision_date',
#        'employer_address_1', 'employer_address_2', 'employer_city',
#        'employer_country', 'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
# ...

# %%
df['case_number']
# Out:
# 0         238418
# 1         238418
# 2         238418
# 3         238418
# 4         238418
#            ...
# 374357    238406
# 374358    235675
# 374359    238387
# 374360    238396
# 374361    236714
# Name: case_number, Length: 374362, dtype: int64

# %%
df['case_no']
# Out:
# 0             49
# 1             51
# 2             52
# 3             53
# 4             56
#            ...
# 374357    134990
# 374358    134990
# 374359    134990
# 374360    134990
# 374361    134990
# Name: case_no, Length: 374362, dtype: int64

# %%
df.drop("case_no", axis =1, inplace=True)

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        'country_of_citizenship', 'country_of_citzenship', 'decision_date',
#        'employer_address_1', 'employer_address_2', 'employer_city',
#        'employer_country', 'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
# ...

# %%
df.case_status
# Out:
# 0         0
# 1         2
# 2         0
# 3         0
# 4         0
#          ..
# 374357    3
# 374358    3
# 374359    3
# 374360    3
# 374361    3
# Name: case_status, Length: 374362, dtype: int64

# %%
df = df[df["case_status"] != "Withdrawn"] #withdarawn application should not be analysed
# withdrawn application should not be analysed because we are not interest knowing who has us vvisa status as withdrawn 
# we interested knowing either approved or denied

# %%
df.case_status.unique()
# Out:
# array([0, 2, 1, 3], dtype=int64)

# %%
df.loc[df.case_status == 'Certified-Expired', 'case_status'] = 'Certified'
# for replacing the word with someother word by using map or str.replace or using below line 
# df.loc[df.case_status == 'Certified-Expired', 'case_status'] = 'Certified' 
# the above line is syntax 
# loc: location based finding the data 
# loc: where ever the value 'Certified-Expired' is there give that column and replace  
# the 'Certified-Expired' columnas 'Certified' 
# Here considering only one column as 'Certified' instead of two columns 'Certified-Expired', 'Certified'

# %%
df.case_status.unique()
# Out:
# array([0, 2, 1, 3], dtype=object)

# %%
df.case_status.value_counts(normalize = True)
# Out:
# case_status
# 0    0.485981
# 1    0.396905
# 2    0.068514
# 3    0.048600
# Name: proportion, dtype: float64

# %%
#insights >>  only 7% people were denied

# %%
# Drop NULL values in all rows and all columns 
df.dropna(axis = 1, how='all', inplace = True)

# %%
df.dropna(axis = 0, how='all', inplace = True)

# %%
df.shape
# Out:
# (374362, 153)

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_number', 'case_received_date',
#        'case_status', 'class_of_admission', 'country_of_citizenship',
#        ...
#        'ri_pvt_employment_firm_to', 'ri_us_workers_considered',
#        'schd_a_sheepherder', 'us_economic_sector', 'wage_offer_from_9089',
#        'wage_offer_to_9089', 'wage_offer_unit_of_pay_9089',
#        'wage_offered_from_9089', 'wage_offered_to_9089',
#        'wage_offered_unit_of_pay_9089'],
#       dtype='object', length=153)

# %%
df.application_type
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 374357    3
# 374358    3
# 374359    3
# 374360    3
# 374361    3
# Name: application_type, Length: 374362, dtype: int64

# %%
df['application_type'].value_counts().plot(kind = 'bar', color = 'red')
# Out:
# <Axes: xlabel='application_type'>

# %%
#most people online

# %%
sns.countplot(data=df, x = 'application_type')
# Out:
# <Axes: xlabel='application_type', ylabel='count'>

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_number', 'case_received_date',
#        'case_status', 'class_of_admission', 'country_of_citizenship',
#        ...
#        'ri_pvt_employment_firm_to', 'ri_us_workers_considered',
#        'schd_a_sheepherder', 'us_economic_sector', 'wage_offer_from_9089',
#        'wage_offer_to_9089', 'wage_offer_unit_of_pay_9089',
#        'wage_offered_from_9089', 'wage_offered_to_9089',
#        'wage_offered_unit_of_pay_9089'],
#       dtype='object', length=153)

# %%
df.us_economic_sector
# Out:
# 0                            IT
# 1         Other Economic Sector
# 2                     Aerospace
# 3         Other Economic Sector
# 4                  Advanced Mfg
#                   ...
# 374357                      NaN
# 374358                      NaN
# 374359                      NaN
# 374360                      NaN
# 374361                      NaN
# Name: us_economic_sector, Length: 374362, dtype: object

# %%
economic_sector = df['us_economic_sector'].value_counts()

# %%
economic_sector
# Out:
# us_economic_sector
# IT                       52617
# Advanced Mfg             18749
# Other Economic Sector    15798
# Finance                   9224
# Educational Services      9130
# Health Care               6825
# Retail                    4408
# Aerospace                 4166
# Hospitality               1926
# Construction              1409
# Automotive                1163
# Energy                    1086
# Transportation             949
# Agribusiness               939
# Biotechnology              456
# Geospatial                 141
# Homeland Security           82
# Name: count, dtype: int64

# %%
plt.figure(figsize = (8, 8))
plt.pie(economic_sector, labels= economic_sector.index, autopct = '%1.1f%%')
plt.show()

# %%
#insights for above chart you will get US visa IT

df['decision_date'] = pd.to_datetime(df['decision_date'])
df['year'] = df['decision_date'].dt.year

# %%
df['year']
# Out:
# 0         1970
# 1         1970
# 2         1970
# 3         1970
# 4         1970
#           ...
# 374357    1970
# 374358    1970
# 374359    1970
# 374360    1970
# 374361    1970
# Name: year, Length: 374362, dtype: int32

# %%
fig, ax = plt.subplots(figsize = (10, 8))

sns.countplot(x = 'year', hue='case_status', data=df)
ax.set(xlabel = "Visa application year", ylabel = "No of applications")
plt.show()

# %%
#insights as application increase, denied and accepted both increasing

# %%
fig, ax = plt.subplots(figsize = (10, 8))

sns.countplot(x = 'employer_city', hue='year', data=df, order = df.employer_city.value_counts().iloc[:10].index)
ax.set(xlabel = "Visa application year", ylabel = "No of applications")
plt.xticks(rotation =90)
plt.show()

# %% [markdown]
# Encoding Data

# %%
from sklearn.preprocessing import LabelEncoder
categorical_variables = {}

# Creating categories denoted by integres from column values
for col in df.columns:
    # print(col)
    cat_var_name = "cat_" + col
    cat_var_name = LabelEncoder()
    cat_var_name.fit(df[col])
    df[col] = cat_var_name.transform(df[col])
    categorical_variables[col] = cat_var_name

df.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\sklearn\utils\_encode.py:174, in _unique_python(values, return_inverse, return_counts)
#     172 uniques_set, missing_values = _extract_missing(uniques_set)
# --> 174 uniques = sorted(uniques_set)
#     175 uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 9
#       7 cat_var_name = "cat_" + col
#       8 cat_var_name = LabelEncoder()
# ----> 9 cat_var_name.fit(df[col])
#      10 df[col] = cat_var_name.transform(df[col])
#      11 categorical_variables[col] = cat_var_name
#
# ...

# %%
# finally now we can do train test split, do scaling and start training model

# %%
# observations: 
# 1. data ingestion 
# 2. Don't consider redudant data or duplicate data, drop either one of them 
#    Example: 
#       case no, case number 
#            or  
#       you can merge it 



# Doubts: 
# 1. When Data set is given and Big problem statement also given 
# S. from data set generate insights. 

# Insights: 
# a. Which type of people will default, may be like salary column, location column, geographical area column. 
# When ever big problem statement is given dive deeper into it. 
# If need more clarifications or discussion the connect to business team  

# Example: 
# Problem Statement: 

# Q. Many people are taking loans but not paying money, is there any person defaulter or not? 
# S. Data set contains information about people that they have taken loan, did they repaid it or not. 
 
# 2. a. check basic data checks 
#    b. see the functions like describe(), info() 
#    c. covert string column to integer column 
#    d. integer column convert into string representation 
#    e. then start with univariate, bivariate, multivariate 

# 3. If you have 1000 columns then we can select relevant columns there are other techniques, machine learning: dimensionality reduction technique is available
